# %%
import os, csv
import pandas as pd
import numpy as np
from keras.preprocessing import sequence
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras import layers, Input
from keras.optimizers import RMSprop, Adam
from sklearn.model_selection import train_test_split
from keras.losses import KLDivergence

from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility

import csv
import os,random

from keras.models import Sequential
from keras.layers import Dense, Bidirectional, LSTM
from keras.layers.convolutional import Convolution1D
from keras.layers.core import Dropout, Activation, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import *
from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from math import sqrt

import datetime
now = datetime.datetime.now

# %%
def process(temp):
    min_len = 3000
    for i in range(11):
        j = 0
        while temp[j][i] != '' and j<len(temp)-1:
            j+=1
        min_len = min(min_len, j);
#     print(min_len)
    return temp[:min_len]

# %%
types = {'B_ID':8, 'E_ID':16, 'NE_ID':27, 'S_ID':10, 'P_ID':16}
x_val = []
x_id = []
for ids, vals in types.items():
    for i in range(1,vals+1):
        x_id.append(ids + str(i))
        try: 
            with open("../po-cf-ex-1-features/"+ids+str(i)+".csv", 'r') as f:
                temp = list(csv.reader(f, delimiter = ","))
            temp = process(temp)
            temp = np.asarray(temp)
            temp = temp.astype(np.float64)
        except:
            print("Problem in:", ids, i)
            continue
        x_val.append(temp)

# x_val = np.asarray(sequence.pad_sequences(x_val, maxlen=600)).astype(np.float64)
print(len(x_val))
for i in range(len(x_val)):
    print(i,x_val[i].shape)
# Out:
# 77
# 0 (490, 11)
# 1 (889, 11)
# 2 (464, 11)
# 3 (537, 11)
# 4 (981, 11)
# 5 (682, 11)
# 6 (546, 11)
# 7 (865, 11)
# 8 (1119, 11)
# 9 (784, 11)
# 10 (637, 11)
# 11 (576, 11)
# 12 (420, 11)
# 13 (505, 11)
# 14 (933, 11)
# 15 (587, 11)
# 16 (422, 11)
# 17 (913, 11)
# 18 (838, 11)
# 19 (739, 11)
# 20 (584, 11)
# 21 (553, 11)
# 22 (503, 11)
# 23 (492, 11)
# 24 (505, 11)
# 25 (555, 11)
# 26 (897, 11)
# 27 (1079, 11)
# 28 (905, 11)
# 29 (1120, 11)
# 30 (612, 11)
# 31 (520, 11)
# 32 (402, 11)
# 33 (492, 11)
# 34 (699, 11)
# 35 (429, 11)
# 36 (299, 11)
# 37 (553, 11)
# 38 (823, 11)
# 39 (988, 11)
# 40 (768, 11)
# 41 (802, 11)
# 42 (883, 11)
# 43 (1500, 11)
# 44 (562, 11)
# 45 (606, 11)
# 46 (384, 11)
# 47 (762, 11)
# 48 (511, 11)
# 49 (608, 11)
# 50 (798, 11)
# 51 (2472, 11)
# 52 (684, 11)
# 53 (273, 11)
# 54 (691, 11)
# 55 (1207, 11)
# 56 (390, 11)
# 57 (959, 11)
# 58 (1079, 11)
# 59 (988, 11)
# 60 (1144, 11)
# 61 (581, 11)
# 62 (487, 11)
# 63 (1206, 11)
# 64 (766, 11)
# 65 (1528, 11)
# 66 (377, 11)
# 67 (553, 11)
# 68 (444, 11)
# 69 (461, 11)
# 70 (590, 11)
# 71 (484, 11)
# 72 (525, 11)
# 73 (438, 11)
# 74 (643, 11)
# 75 (517, 11)
# 76 (685, 11)

# %%
po_val = []
cf_val = []
for ids in x_id:
    try:
        df = pd.read_excel("../KiMoRe/"+ids+"/Es1/Label/ClinicalAssessment_"+ids+".xlsx")
    except:
        print("problem in: ", ids)
        continue
    df = np.array(df).reshape((16,))
    po_val.append(df[6])
    cf_val.append(df[11])
po_val = np.asarray(po_val).astype(np.float64)
cf_val = np.asarray(cf_val).astype(np.float64)
ts_val = po_val+cf_val
print("shape of CF: ", cf_val.shape)
print("shape of PO: ", po_val.shape)
print("shape of TS: ", ts_val.shape)
# print(po_val)
for i in range(len(ts_val)):
    if np.isnan(ts_val[i]):
        print(i,x_id[i])
print(ts_val)
# Out:
# /home/yash/.local/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# shape of CF:  (77,)
# shape of PO:  (77,)
# shape of TS:  (77,)
# [41.         38.         28.21008112 33.3397327  44.33333333 45.33333333
#  40.33333333 44.33333333 48.33333333 49.33333333 42.66666667 44.66666667
#  46.         46.66666667 50.         48.66666667 50.         48.33333333
#  50.         50.         46.33333333 44.         50.         47.
#  39.66666667 41.         44.33333333 46.33333333 40.66666667 43.66666667
#  42.         40.         42.         34.         46.         40.
#  50.         50.         45.         47.         47.         38.
#  50.         46.         46.         43.         41.         50.
#  47.         49.         49.         27.         34.         44.
#  26.         32.89508774 38.41075339 26.66666667 36.         26.33333333
#  33.66666667 48.         27.         50.         14.         33.
#  50.         22.         32.         40.         34.3081805  14.66666667
#  35.66666667 36.66666667 36.         27.66666667 37.        ]

# %%
for i in range(77):
    if x_val[i].shape[0]==562:
        print(i)
# Out:
# 44

# %%
length = len(ts_val)

# %%
def jumble_up(val):
    return np.random.permutation(val)

# %%
indices = np.arange(len(ts_val))
indices = jumble_up(indices)
temp_x = x_val
x_val = []
temp_ts = ts_val
ts_val = []
for i in range(length):
    print(i)
    x_val.append(temp_x[indices[i]])
    ts_val.append(temp_ts[indices[i]])
    print(x_val[i].shape)
# Out:
# 0
# (612, 11)
# 1
# (553, 11)
# 2
# (883, 11)
# 3
# (429, 11)
# 4
# (637, 11)
# 5
# (553, 11)
# 6
# (682, 11)
# 7
# (555, 11)
# 8
# (905, 11)
# 9
# (1079, 11)
# 10
# (490, 11)
# 11
# (959, 11)
# 12
# (517, 11)
# 13
# (606, 11)
# 14
# (390, 11)
# 15
# (1207, 11)
# 16
# (422, 11)
# 17
# (988, 11)
# 18
# (1206, 11)
# 19
# (505, 11)
# 20
# (273, 11)
# 21
# (562, 11)
# 22
# (299, 11)
# 23
# (1120, 11)
# 24
# (1144, 11)
# 25
# (461, 11)
# 26
# (587, 11)
# 27
# (402, 11)
# 28
# (553, 11)
# 29
# (699, 11)
# 30
# (438, 11)
# 31
# (933, 11)
# 32
# (684, 11)
# 33
# (823, 11)
# 34
# (487, 11)
# 35
# (897, 11)
# 36
# (838, 11)
# 37
# (608, 11)
# 38
# (1500, 11)
# 39
# (766, 11)
# 40
# (420, 11)
# 41
# (492, 11)
# 42
# (520, 11)
# 43
# (981, 11)
# 44
# (484, 11)
# 45
# (2472, 11)
# 46
# (865, 11)
# 47
# (511, 11)
# 48
# (1119, 11)
# 49
# (584, 11)
# 50
# (537, 11)
# 51
# (1528, 11)
# 52
# (762, 11)
# 53
# (913, 11)
# 54
# (384, 11)
# 55
# (739, 11)
# 56
# (444, 11)
# 57
# (377, 11)
# 58
# (576, 11)
# 59
# (768, 11)
# 60
# (802, 11)
# 61
# (464, 11)
# 62
# (798, 11)
# 63
# (503, 11)
# 64
# (590, 11)
# 65
# (1079, 11)
# 66
# (889, 11)
# 67
# (505, 11)
# 68
# (685, 11)
# 69
# (691, 11)
# 70
# (546, 11)
# 71
# (784, 11)
# 72
# (525, 11)
# 73
# (643, 11)
# 74
# (988, 11)
# 75
# (581, 11)
# 76
# (492, 11)

# %%
for i in range(length):
    if x_val[i].shape[0]==562:
        print(i)
# Out:
# 21

# %%
max_x_val = -1
max_ts_val = -1
for i in range(len(ts_val)):
    max_x_val = max(max_x_val, np.max(np.abs(x_val[i])))
    max_ts_val = max(max_ts_val, np.max(np.abs(ts_val[i])))
x_val = x_val/max_x_val
ts_val = ts_val/max_ts_val
x_train, x_test, y_train, y_test = train_test_split(x_val,ts_val, test_size=0.3)
print(x_test.shape)
print(x_train.shape)
# Out:
# (24,)
# (53,)
# <ipython-input-10-7e8cac94481f>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_val = x_val/max_x_val

# %%
# timesteps = 600 
nr = 77   
n_dim = 11  
dropout_rate = 0.1

# %%
def train_generator(lim):
    n=0
    while n<lim:
        i = n%53
        xt = []
        yt = []
        xt.append(x_train[i])
        yt.append(y_train[i])
        xt = np.array(xt).astype('float32')
        yt = np.array(yt).astype('float32')
        yield xt,yt
        n+=1

# %%
def val_generator(lim):
    n=0
    while n<lim:
        i = n%24
        xt = []
        yt = []
        xt.append(x_test[i])
        yt.append(y_test[i])
        xt = np.array(xt).astype('float32')
        yt = np.array(yt).astype('float32')
        yield xt,yt
        n+=1

# %%
for i in range(53):
    print(x_train[i].shape)
print("---------")
for i in range(24):
    print(x_test[i].shape)
# Out:
# (865, 11)
# (587, 11)
# (576, 11)
# (883, 11)
# (699, 11)
# (1120, 11)
# (444, 11)
# (988, 11)
# (581, 11)
# (438, 11)
# (377, 11)
# (546, 11)
# (762, 11)
# (492, 11)
# (299, 11)
# (520, 11)
# (889, 11)
# (933, 11)
# (484, 11)
# (584, 11)
# (384, 11)
# (637, 11)
# (1079, 11)
# (553, 11)
# (420, 11)
# (823, 11)
# (988, 11)
# (553, 11)
# (959, 11)
# (1079, 11)
# (555, 11)
# (768, 11)
# (612, 11)
# (1207, 11)
# (2472, 11)
# (517, 11)
# (492, 11)
# (429, 11)
# (503, 11)
# (402, 11)
# (784, 11)
# (643, 11)
# (505, 11)
# (490, 11)
# (682, 11)
# (1119, 11)
# (553, 11)
# (422, 11)
# (590, 11)
# (1528, 11)
# (1500, 11)
# (273, 11)
# (464, 11)
# ---------
# (691, 11)
# (505, 11)
# (525, 11)
# (461, 11)
# (766, 11)
# (562, 11)
# (537, 11)
# (905, 11)
# (608, 11)
# (684, 11)
# (606, 11)
# (487, 11)
# (838, 11)
# (798, 11)
# (913, 11)
# (897, 11)
# (981, 11)
# (1144, 11)
# (390, 11)
# (739, 11)
# (1206, 11)
# (511, 11)
# (802, 11)
# (685, 11)

# %%
def Network():
    model = Sequential()

    model.add(Bidirectional(LSTM(128, recurrent_dropout = 0.2, return_sequences = True), input_shape = (None,n_dim)))
    model.add(Dropout(0.3))

    model.add(Bidirectional(LSTM(64, recurrent_dropout = 0.1,return_sequences = True)))
    model.add(Dropout(0.2))
    model.add(Convolution1D(16, 1))

    model.add(Convolution1D(8, 1))
    
    model.add(Bidirectional(LSTM(32)))
    model.add(Dense(1,activation='sigmoid'))

    print(model.summary())
    model.compile(loss='binary_crossentropy',metrics=['accuracy'], optimizer=Adam())
    # Early stopping if the validaton Loss does not decrease for 100 epochs
    early_stopping = EarlyStopping(monitor='val_loss', patience = 100)

    t = now()
    history = model.fit(train_generator(3000),steps_per_epoch=10, epochs=100, verbose=1,
                        validation_data=val_generator(3000),validation_steps=2,callbacks = [early_stopping])
    print('training time')
    print(now() - t)
    
    # Plot the results
    plt.figure(1)
    plt.subplot(221)
    plt.plot(history.history['loss'])
    plt.title('Training Loss')
    plt.subplot(222)
    plt.plot(history.history['val_loss'])
    plt.title('Validation Loss')
    plt.tight_layout()
    plt.show()
    
    # Plot the prediction of the CNN model for the training and validation sets
    pred_test = []
    for i in range(24):
        xt = []
        xt.append(x_test[i])
        xt = np.array(xt).astype('float32')        
        prediction = model.predict(xt)
        pred_test.append(prediction)
    pred_test = np.array(pred_test).astype('float32') 
    pred_test = pred_test.reshape(24)
    pred_train = []
    for i in range(53):
        xt = []
        xt.append(x_train[i])
        xt = np.array(xt).astype('float32')
        pred_train.append(model.predict(xt))
    pred_train = np.array(pred_train).astype('float32') 
    print(pred_train.shape)
    
    
    pred_train = pred_train.reshape(53)
    plt.figure(figsize = (8,8))
    plt.subplot(2,1,1)
    plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
    plt.plot(y_train,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
    plt.ylim([-0.1,1.1])
    plt.title('Training Set',fontsize=18)
    plt.xlabel('Sequence Number',fontsize=16)
    plt.ylabel('Quality Scale',fontsize=16)
    plt.legend(loc=3, prop={'size':14}) # loc:position
    plt.subplot(2,1,2)
    plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
    plt.plot(y_test,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
    plt.title('Testing Set',fontsize=18)
    plt.ylim([-0.1,1.1])
    plt.xlabel('Sequence Number',fontsize=16)
    plt.ylabel('Quality Score',fontsize=16)
    plt.legend(loc=3, prop={'size':14}) 
    plt.tight_layout()
    plt.show()
    
    
    test_dev = abs(np.squeeze(pred_test)-y_test)
    mean_abs_dev = np.mean(test_dev)
    rms_dev = sqrt(mean_squared_error(pred_test, y_test))
    print('Mean absolute deviation:', mean_abs_dev)
    print('RMS deviation:', rms_dev)
    
    return mean_abs_dev, rms_dev

# %%
Mean_abs_dev, RMS_dev  = Network()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_59 (Bidirectio (None, None, 256)         143360
# _________________________________________________________________
# dropout_58 (Dropout)         (None, None, 256)         0
# _________________________________________________________________
# bidirectional_60 (Bidirectio (None, None, 128)         164352
# _________________________________________________________________
# dropout_59 (Dropout)         (None, None, 128)         0
# _________________________________________________________________
# conv1d_60 (Conv1D)           (None, None, 16)          2064
# _________________________________________________________________
# conv1d_61 (Conv1D)           (None, None, 8)           136
# _________________________________________________________________
# bidirectional_61 (Bidirectio (None, 64)                10496
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 320,473
# Trainable params: 320,473
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 22s 1s/step - loss: 0.5736 - accuracy: 0.1087 - val_loss: 0.6134 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3352 - accuracy: 0.5400 - val_loss: 1.0110 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.5354 - accuracy: 0.0000e+00 - val_loss: 0.5808 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.5278 - accuracy: 0.0283 - val_loss: 0.5415 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4228 - accuracy: 0.0923 - val_loss: 0.2016 - val_accuracy: 0.5000
# Epoch 6/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4068 - accuracy: 0.0526 - val_loss: 0.3561 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 10/10 [==============================] - 10s 962ms/step - loss: 0.5229 - accuracy: 0.2161 - val_loss: 0.3611 - val_accuracy: 0.5000
# Epoch 8/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5635 - accuracy: 0.2754 - val_loss: 0.4256 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.5310 - accuracy: 0.0000e+00 - val_loss: 0.5918 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4251 - accuracy: 0.2026 - val_loss: 0.8438 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4535 - accuracy: 0.2935 - val_loss: 0.6005 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4715 - accuracy: 0.0809 - val_loss: 0.5601 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4591 - accuracy: 0.3841 - val_loss: 0.1918 - val_accuracy: 0.5000
# Epoch 14/100
# 10/10 [==============================] - 14s 2s/step - loss: 0.3912 - accuracy: 0.0000e+00 - val_loss: 0.3752 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 10/10 [==============================] - 14s 929ms/step - loss: 0.6562 - accuracy: 0.0860 - val_loss: 0.4010 - val_accuracy: 0.5000
# Epoch 16/100
# 10/10 [==============================] - 15s 1s/step - loss: 0.3836 - accuracy: 0.2477 - val_loss: 0.4254 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.3572 - accuracy: 0.1572 - val_loss: 0.6285 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3893 - accuracy: 0.3458 - val_loss: 0.9601 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.5451 - accuracy: 0.0000e+00 - val_loss: 0.5929 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.5307 - accuracy: 0.0396 - val_loss: 0.5398 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.4714 - accuracy: 0.1204 - val_loss: 0.2285 - val_accuracy: 0.5000
# Epoch 22/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4563 - accuracy: 0.0678 - val_loss: 0.3653 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3429 - accuracy: 0.2958 - val_loss: 0.3637 - val_accuracy: 0.5000
# Epoch 24/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.7236 - accuracy: 0.0000e+00 - val_loss: 0.4243 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.6034 - accuracy: 0.0000e+00 - val_loss: 0.5970 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3684 - accuracy: 0.3218 - val_loss: 0.8600 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.5332 - accuracy: 0.0283 - val_loss: 0.5981 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 10/10 [==============================] - 11s 976ms/step - loss: 0.5151 - accuracy: 0.1256 - val_loss: 0.5575 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5608 - accuracy: 0.1390 - val_loss: 0.1981 - val_accuracy: 0.5000
# Epoch 30/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4260 - accuracy: 0.0000e+00 - val_loss: 0.3743 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 10/10 [==============================] - 10s 986ms/step - loss: 0.5845 - accuracy: 0.1087 - val_loss: 0.3911 - val_accuracy: 0.5000
# Epoch 32/100
# 10/10 [==============================] - 15s 1s/step - loss: 0.3767 - accuracy: 0.3234 - val_loss: 0.4264 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4032 - accuracy: 0.2127 - val_loss: 0.6213 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3479 - accuracy: 0.4821 - val_loss: 0.9438 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.5904 - accuracy: 0.0000e+00 - val_loss: 0.5930 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.6116 - accuracy: 0.0526 - val_loss: 0.5398 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4236 - accuracy: 0.1538 - val_loss: 0.2252 - val_accuracy: 0.5000
# Epoch 38/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4951 - accuracy: 0.0860 - val_loss: 0.3659 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.4069 - accuracy: 0.3892 - val_loss: 0.3651 - val_accuracy: 0.5000
# Epoch 40/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4684 - accuracy: 0.0000e+00 - val_loss: 0.4244 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4724 - accuracy: 0.0182 - val_loss: 0.6023 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4139 - accuracy: 0.0679 - val_loss: 0.8658 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 10/10 [==============================] - 16s 1s/step - loss: 0.4914 - accuracy: 0.0396 - val_loss: 0.5946 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 10/10 [==============================] - 10s 989ms/step - loss: 0.5633 - accuracy: 0.1669 - val_loss: 0.5546 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5717 - accuracy: 0.1845 - val_loss: 0.2017 - val_accuracy: 0.5000
# Epoch 46/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4613 - accuracy: 0.0000e+00 - val_loss: 0.3733 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4803 - accuracy: 0.1390 - val_loss: 0.3860 - val_accuracy: 0.5000
# Epoch 48/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3981 - accuracy: 0.4598 - val_loss: 0.4272 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4054 - accuracy: 0.3332 - val_loss: 0.6192 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4084 - accuracy: 0.2704 - val_loss: 0.9320 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5818 - accuracy: 0.0000e+00 - val_loss: 0.5938 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 10/10 [==============================] - 15s 1s/step - loss: 0.6748 - accuracy: 0.0678 - val_loss: 0.5410 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.3995 - accuracy: 0.1947 - val_loss: 0.2244 - val_accuracy: 0.5000
# Epoch 54/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3711 - accuracy: 0.1087 - val_loss: 0.3673 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3314 - accuracy: 0.5400 - val_loss: 0.3662 - val_accuracy: 0.5000
# Epoch 56/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5264 - accuracy: 0.0000e+00 - val_loss: 0.4247 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.5285 - accuracy: 0.0283 - val_loss: 0.6023 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4020 - accuracy: 0.0923 - val_loss: 0.8714 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4126 - accuracy: 0.0526 - val_loss: 0.5953 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 10/10 [==============================] - 10s 971ms/step - loss: 0.5066 - accuracy: 0.2161 - val_loss: 0.5548 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5523 - accuracy: 0.2754 - val_loss: 0.2028 - val_accuracy: 0.5000
# Epoch 62/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.5343 - accuracy: 0.0000e+00 - val_loss: 0.3751 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4051 - accuracy: 0.2026 - val_loss: 0.3839 - val_accuracy: 0.5000
# Epoch 64/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4510 - accuracy: 0.2935 - val_loss: 0.4264 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4691 - accuracy: 0.0809 - val_loss: 0.6207 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4570 - accuracy: 0.3841 - val_loss: 0.9248 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 10/10 [==============================] - 14s 2s/step - loss: 0.3905 - accuracy: 0.0000e+00 - val_loss: 0.5937 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 10/10 [==============================] - 14s 949ms/step - loss: 0.6631 - accuracy: 0.0860 - val_loss: 0.5416 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.3731 - accuracy: 0.2477 - val_loss: 0.2235 - val_accuracy: 0.5000
# Epoch 70/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.3641 - accuracy: 0.1572 - val_loss: 0.3676 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3907 - accuracy: 0.3458 - val_loss: 0.3672 - val_accuracy: 0.5000
# Epoch 72/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.5391 - accuracy: 0.0000e+00 - val_loss: 0.4250 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.5306 - accuracy: 0.0396 - val_loss: 0.6021 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 10/10 [==============================] - 15s 1s/step - loss: 0.4688 - accuracy: 0.1204 - val_loss: 0.8737 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4553 - accuracy: 0.0678 - val_loss: 0.5946 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3475 - accuracy: 0.2958 - val_loss: 0.5552 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.7081 - accuracy: 0.0000e+00 - val_loss: 0.2032 - val_accuracy: 0.5000
# Epoch 78/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.6031 - accuracy: 0.0000e+00 - val_loss: 0.3764 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3560 - accuracy: 0.3218 - val_loss: 0.3813 - val_accuracy: 0.5000
# Epoch 80/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.5349 - accuracy: 0.0283 - val_loss: 0.4254 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 10/10 [==============================] - 11s 971ms/step - loss: 0.5109 - accuracy: 0.1256 - val_loss: 0.6238 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5567 - accuracy: 0.1390 - val_loss: 0.9221 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4279 - accuracy: 0.0000e+00 - val_loss: 0.5925 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 10/10 [==============================] - 10s 977ms/step - loss: 0.5837 - accuracy: 0.1087 - val_loss: 0.5414 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.3721 - accuracy: 0.3234 - val_loss: 0.2224 - val_accuracy: 0.5000
# Epoch 86/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4045 - accuracy: 0.2127 - val_loss: 0.3675 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.3505 - accuracy: 0.4821 - val_loss: 0.3675 - val_accuracy: 0.5000
# Epoch 88/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.5839 - accuracy: 0.0000e+00 - val_loss: 0.4252 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 10/10 [==============================] - 16s 2s/step - loss: 0.6138 - accuracy: 0.0526 - val_loss: 0.6022 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 10/10 [==============================] - 14s 1s/step - loss: 0.4189 - accuracy: 0.1538 - val_loss: 0.8775 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4977 - accuracy: 0.0860 - val_loss: 0.5944 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.4070 - accuracy: 0.3892 - val_loss: 0.5542 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4687 - accuracy: 0.0000e+00 - val_loss: 0.2072 - val_accuracy: 0.5000
# Epoch 94/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.4734 - accuracy: 0.0182 - val_loss: 0.3779 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4135 - accuracy: 0.0679 - val_loss: 0.3804 - val_accuracy: 0.5000
# Epoch 96/100
# 10/10 [==============================] - 16s 1s/step - loss: 0.4928 - accuracy: 0.0396 - val_loss: 0.4252 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 10/10 [==============================] - 10s 981ms/step - loss: 0.5594 - accuracy: 0.1669 - val_loss: 0.6233 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5684 - accuracy: 0.1845 - val_loss: 0.9150 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4615 - accuracy: 0.0000e+00 - val_loss: 0.5904 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.4794 - accuracy: 0.1390 - val_loss: 0.5420 - val_accuracy: 0.0000e+00
# training time
# 0:22:08.467977
# (53, 1, 1)
# Mean absolute deviation: 0.14267719361837666
# RMS deviation: 0.1781002389139188

# %%
print(3e-4)
